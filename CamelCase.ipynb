# %% [markdown]
# ![image.png](attachment:image.png)

# %%
valor=0
text=""
if  text=="" or text[0].islower():
        valor=1
print(valor)
# Out:
# 0

# %% [markdown]
# Comprueba si la primera letra de la palabra es mayuscula o si el caracter esta vacío y almacena un 1 en la variable valor

# %%
import re
text="hola_primero-dam"
text=re.split("[_-]", text)

text
# Out:
# ['hola', 'primero', 'dam']

# %% [markdown]
# Separa por - y _

# %%
if valor==1:
        vuelta+=text[0]

# %% [markdown]
# Si la primera letra de la palabra es miniscula suma el primer valor de la lista

# %%
for i in range (valor, len(text)):
        text[i]=text[i].capitalize()
        vuelta+=text[i]

# %% [markdown]
# Convierte la primera letra de las Strings de la lista en mayuscula y lo suma a la variable que vamos a devolver.(Reutilizamor la variable valor para determinar el rango y asi no copiar dos veces la primera palabra de la lista)
